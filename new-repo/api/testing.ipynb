# %%
import json
with open('../tests/vehicles_data.json', 'r') as f:
        test_data = json.loads(f.read())

with open('../tests/vin_data.json', 'r') as f:
        vin_data = json.loads(f.read())

# %%
print(type(test_data))
print(type(vin_data))

# %%
hmm = {}
tmp = []
for dealer in range(0, len(t)):
  for k, v in t[dealer].items():
    if 'vehicles' in k:
      hmm = t[dealer]
      for i in range(0, len(v)):
        # print(t[dealer]['vehicles'][i])
        tmp.append({**t[dealer], **t[dealer]['vehicles'][i]})

for i in range(0, len(tmp)):
  del tmp[i]['vehicles']

# %%
json.dumps(tmp)

# %%
import json
import pprint

def flatten_api_results(input_data: str):
  tmp = []
  input_data = input_data['data'][0]['dealerInfo']

  if input_data:
    for dealer in range(0, len(input_data)):
      for k, v in input_data[dealer].items():
        if 'vehicles' in k and v is not None:
          for i in range(0, len(v)):
            tmp.append({**input_data[dealer], **input_data[dealer]['vehicles'][i]})

    for i in range(0, len(tmp)):
        del tmp[i]['vehicles']

        tmp[i]['ExtColorLongDesc'] = tmp[i]['colors'][0]['ExtColorLongDesc']

    return json.dumps(tmp)
  else:
    return json.dumps({})

flatten_api_results(test_data)

# %%
d = json.loads('{"status":"SUCCESS","data":[{"modelYear":2022,"yrSerCd":"20225","dealerInfo":null}]}')

input_data = d['data'][0]['dealerInfo']

bool(input_data)

# %%
import json

d = {
  "status": "SUCCESS",
  "data": [
    {
      "total": 1960,
      "models": [
        {
          "modelYear": 2020,
          "modelNm": "Elantra",
          "seriesCd": "4",
          "modelGroupCd": "4001",
          "count": 3
        },
        {
          "modelYear": 2020,
          "modelNm": "Ioniq Hev",
          "seriesCd": "N",
          "modelGroupCd": "N006",
          "count": 1
        },
        {
          "modelYear": 2020,
          "modelNm": "Kona",
          "seriesCd": "Q",
          "modelGroupCd": "Q001",
          "count": 1
        },
        {
          "modelYear": 2020,
          "modelNm": "Santa Fe",
          "seriesCd": "6",
          "modelGroupCd": "6001",
          "count": 3
        },
        {
          "modelYear": 2020,
          "modelNm": "Tucson",
          "seriesCd": "8",
          "modelGroupCd": "8001",
          "count": 3
        },
        {
          "modelYear": 2021,
          "modelNm": "Accent",
          "seriesCd": "1",
          "modelGroupCd": "1001",
          "count": 1
        },
        {
          "modelYear": 2021,
          "modelNm": "Elantra",
          "seriesCd": "4",
          "modelGroupCd": "4001",
          "count": 6
        },
        {
          "modelYear": 2021,
          "modelNm": "Ioniq Hev",
          "seriesCd": "N",
          "modelGroupCd": "N006",
          "count": 1
        },
        {
          "modelYear": 2021,
          "modelNm": "Ioniq Phev",
          "seriesCd": "N",
          "modelGroupCd": "N005",
          "count": 2
        },
        {
          "modelYear": 2021,
          "modelNm": "Kona Ev",
          "seriesCd": "Q",
          "modelGroupCd": "Q004",
          "count": 2
        },
        {
          "modelYear": 2021,
          "modelNm": "Palisade",
          "seriesCd": "J",
          "modelGroupCd": "J001",
          "count": 8
        },
        {
          "modelYear": 2021,
          "modelNm": "Santa Fe",
          "seriesCd": "6",
          "modelGroupCd": "6001",
          "count": 1
        },
        {
          "modelYear": 2021,
          "modelNm": "Sonata",
          "seriesCd": "2",
          "modelGroupCd": "2001",
          "count": 4
        },
        {
          "modelYear": 2021,
          "modelNm": "Tucson",
          "seriesCd": "8",
          "modelGroupCd": "8001",
          "count": 1
        },
        {
          "modelYear": 2022,
          "modelNm": "Accent",
          "seriesCd": "1",
          "modelGroupCd": "1001",
          "count": 18
        },
        {
          "modelYear": 2022,
          "modelNm": "Elantra",
          "seriesCd": "4",
          "modelGroupCd": "4001",
          "count": 184
        },
        {
          "modelYear": 2022,
          "modelNm": "Elantra Hev",
          "seriesCd": "4",
          "modelGroupCd": "4006",
          "count": 43
        },
        {
          "modelYear": 2022,
          "modelNm": "Elantra N",
          "seriesCd": "4",
          "modelGroupCd": "4008",
          "count": 7
        },
        {
          "modelYear": 2022,
          "modelNm": "Ioniq 5",
          "seriesCd": "5",
          "modelGroupCd": "5004",
          "count": 221
        },
        {
          "modelYear": 2022,
          "modelNm": "Ioniq Hev",
          "seriesCd": "N",
          "modelGroupCd": "N006",
          "count": 41
        },
        {
          "modelYear": 2022,
          "modelNm": "Ioniq Phev",
          "seriesCd": "N",
          "modelGroupCd": "N005",
          "count": 84
        },
        {
          "modelYear": 2022,
          "modelNm": "Kona",
          "seriesCd": "Q",
          "modelGroupCd": "Q001",
          "count": 195
        },
        {
          "modelYear": 2022,
          "modelNm": "Kona Ev",
          "seriesCd": "Q",
          "modelGroupCd": "Q004",
          "count": 8
        },
        {
          "modelYear": 2022,
          "modelNm": "Kona N",
          "seriesCd": "Q",
          "modelGroupCd": "Q008",
          "count": 6
        },
        {
          "modelYear": 2022,
          "modelNm": "Palisade",
          "seriesCd": "J",
          "modelGroupCd": "J001",
          "count": 133
        },
        {
          "modelYear": 2022,
          "modelNm": "Santa Cruz",
          "seriesCd": "9",
          "modelGroupCd": "9001",
          "count": 141
        },
        {
          "modelYear": 2022,
          "modelNm": "Santa Fe",
          "seriesCd": "6",
          "modelGroupCd": "6001",
          "count": 191
        },
        {
          "modelYear": 2022,
          "modelNm": "Santa Fe Hev",
          "seriesCd": "6",
          "modelGroupCd": "6006",
          "count": 2
        },
        {
          "modelYear": 2022,
          "modelNm": "Santa Fe Phev",
          "seriesCd": "6",
          "modelGroupCd": "6005",
          "count": 60
        },
        {
          "modelYear": 2022,
          "modelNm": "Sonata",
          "seriesCd": "2",
          "modelGroupCd": "2001",
          "count": 113
        },
        {
          "modelYear": 2022,
          "modelNm": "Sonata Hev",
          "seriesCd": "2",
          "modelGroupCd": "2006",
          "count": 15
        },
        {
          "modelYear": 2022,
          "modelNm": "Tucson",
          "seriesCd": "8",
          "modelGroupCd": "8001",
          "count": 293
        },
        {
          "modelYear": 2022,
          "modelNm": "Tucson Hev",
          "seriesCd": "8",
          "modelGroupCd": "8006",
          "count": 47
        },
        {
          "modelYear": 2022,
          "modelNm": "Tucson Phev",
          "seriesCd": "8",
          "modelGroupCd": "8005",
          "count": 21
        },
        {
          "modelYear": 2022,
          "modelNm": "Veloster N",
          "seriesCd": "F",
          "modelGroupCd": "F008",
          "count": 6
        },
        {
          "modelYear": 2022,
          "modelNm": "Venue",
          "seriesCd": "3",
          "modelGroupCd": "3001",
          "count": 94
        }
      ]
    }
  ]
}

# %%
for i in enumerate(d['data'][0]['models']):
  model_year = i[1]['modelYear']
  count = i[1]['count']
  model_name = i[1]['modelNm']
  
  if model_year == 2022 and count > 0:
    print("{ value: " + f'\'{model_name}\'' + ", text: 'NameHere'},")
# Out:
# { value: 'Accent', text: 'NameHere'},
# { value: 'Elantra', text: 'NameHere'},
# { value: 'Elantra Hev', text: 'NameHere'},
# { value: 'Elantra N', text: 'NameHere'},
# { value: 'Ioniq 5', text: 'NameHere'},
# { value: 'Ioniq Hev', text: 'NameHere'},
# { value: 'Ioniq Phev', text: 'NameHere'},
# { value: 'Kona', text: 'NameHere'},
# { value: 'Kona Ev', text: 'NameHere'},
# { value: 'Kona N', text: 'NameHere'},
# { value: 'Palisade', text: 'NameHere'},
# { value: 'Santa Cruz', text: 'NameHere'},
# { value: 'Santa Fe', text: 'NameHere'},
# { value: 'Santa Fe Hev', text: 'NameHere'},
# { value: 'Santa Fe Phev', text: 'NameHere'},
# { value: 'Sonata', text: 'NameHere'},
# { value: 'Sonata Hev', text: 'NameHere'},
# { value: 'Tucson', text: 'NameHere'},
# { value: 'Tucson Hev', text: 'NameHere'},
# { value: 'Tucson Phev', text: 'NameHere'},
# { value: 'Veloster N', text: 'NameHere'},
# { value: 'Venue', text: 'NameHere'},
